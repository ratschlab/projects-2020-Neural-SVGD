# %% [markdown]
# # Model

# %%
import sys
import os
sys.path.append("/home/lauro/code/msc-thesis/svgd/kernel_learning")
enable_float64 = False
from jax.config import config
config.update("jax_enable_x64", enable_float64)
# config.update("jax_log_compiles", True)

# config.update("jax_debug_nans", True)
import json_tricks as json
import copy

import jax.numpy as np
from jax import grad, jit, vmap, random, lax, jacfwd
from jax import lax
from jax.ops import index_update, index
import matplotlib.pyplot as plt
import numpy as onp
import jax
import pandas as pd
import haiku as hk

import config

import utils
import metrics
import time
import plot
import stein
import kernels
import distributions
from svgd import SVGD

from jax.experimental import optimizers

key = random.PRNGKey(0)
# Out:
# /home/lauro/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/lib/xla_bridge.py:125: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
def plot_rundata(true, *args, labels=None, ax=None, title=None):
    ax = plt.gca() if ax is None else ax
    colorcycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
    styles = ["-", "--", "-.", ":"]
    for data, label, style in zip(args, labels, styles):
        ax.set_prop_cycle(color=colorcycle)
        ax.plot(data, style, label=label)
        length = len(data)

    # True parameters
    _ = ax.hlines(true, 0, length, colors=colorcycle, linestyles="dotted")
    ax.legend()
    ax.set_title(title)

# %% [markdown]
# ## Vanilla ARD

# %%
conf = copy.deepcopy(config.config)

# conf["svgd"]["target"] = "Funnel"
conf["svgd"]["target_args"] = [0, 0.1]
# conf["svgd"]["target_args"] = [2]

# conf["svgd"]["kernel"] = "funnel_optimal_kernel"
conf["svgd"]["kernel"] = "ard"
# conf["svgd"]["kernel"] = "constant"

conf["svgd"]["n_particles"] = 400
conf["svgd"]["n_subsamples"] = 200

conf["train_kernel"]["train"] = False
conf["train_kernel"]["svgd_steps"] = 400
conf["train_kernel"]["n_iter"] = 1 #config.config["train_kernel"]["n_iter"] // conf_mlp["train_kernel"]["svgd_steps"]
conf["train_kernel"]["detailed_log"] = False

# %%
sargs = config.get_svgd_args(conf)
sargs["kernel"] = kernels.get_rbf_kernel(1)

# %%
sargs
# Out:
# {'target': <distributions.Gaussian at 0x7fdd943f3ee0>,
#  'n_particles': 400,
#  'n_subsamples': 200,
#  'subsample_with_replacement': False,
#  'minimize_ksd_variance': True,
#  'optimizer_svgd': <svgd.Optimizer at 0x7fdd4c0a2280>,
#  'kernel': <function kernels.get_rbf_kernel.<locals>.rbf(x, y)>,
#  'encoder': Transformed(init=<function without_state.<locals>.init_fn at 0x7fdd4c8f0af0>, apply=<function without_state.<locals>.apply_fn at 0x7fdd4c8f0a60>),
#  'decoder': None}

# %%
svgd_vanilla = SVGD(**sargs)
key, subkey = random.split(key)
rundata_vanilla = svgd_vanilla.sample(subkey, *config.get_sample_args(conf).values())

t_mean = onp.array(rundata_vanilla["leader_mean"])
t_var = onp.array(rundata_vanilla["leader_var"])
v_mean = onp.array(rundata_vanilla["validation_mean"])
v_var = onp.array(rundata_vanilla["validation_var"])
tru_mean = svgd_vanilla.target.mean
tru_var = onp.diag(svgd_vanilla.target.cov)
# Out:
# 100%|██████████| 400/400 [00:28<00:00, 14.19it/s]

# %%
idx = rundata_vanilla["leader_idx"]
plt.hist(rundata_vanilla["particles"][idx, 0], density=True, bins=25)
plot.plot_fun(distributions.Gaussian(0, .1).pdf, (-1.5, 1.5))
plot.plot_fun(distributions.Gaussian(0, 5).pdf, (-1.5, 1.5))

# %%
fig, axs = plt.subplots(1, 2, figsize=[22, 4])
plot_rundata(tru_mean, t_mean, v_mean, labels=["Leader Mean", "Validation Mean"], ax=axs[0])
plot_rundata(tru_var, t_var, v_var, labels=["Leader Variance", "Validation Variance"], ax=axs[1])

# %%
ladj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-625e370dda2b> in <module>
# ----> 1 ladj
#
# NameError: name 'ladj' is not defined

# %%
# fig, ax = plt.subplots(figsize=[11, 4])
# ax.plot(rundata_vanilla["ksd_after_svgd_update"])
# ax.plot(rundata_vanilla["ksd_after_svgd_update_val"])
# ax.set_yscale("log")

# %%
# fig, axs = plt.subplots(1, 2, figsize=[18, 8])
# axs[0].plot(rundata_vanilla["mean_drift"], label="Mean Drift")
# axs[0].legend()
# axs[1].plot(rundata_vanilla["mean_repulsion"], label="Mean Repulsion")
# axs[1].legend()
# # axs[1].set_yscale("log")

# %% [markdown]
# # MLP Kernel

# %%
conf_mlp = copy.deepcopy(config.config)

conf_mlp["svgd"]["target_args"] = [0, 15]

conf_mlp["svgd"]["n_particles"] = 600
conf_mlp["svgd"]["n_subsamples"] = 200
conf_mlp["svgd"]["encoder_layers"] = [1]
conf_mlp["svgd"]["decoder_layers"] = [1]

conf_mlp["train_kernel"]["ksd_steps"] = 50
conf_mlp["train_kernel"]["svgd_steps"] = 1
conf_mlp["train_kernel"]["n_iter"] = 2
conf_mlp["train_kernel"]["optimizer_ksd_args"] = [10]
conf_mlp["train_kernel"]["lamda_reg"] = 0
conf_mlp["train_kernel"]["minimize_ksd_variance"] = False
conf_mlp["train_kernel"]["detailed_log"] = False

# %%
svgd_mlp = SVGD(**config.get_svgd_args(conf_mlp))

# %% [markdown]
# Maybe with more steps / batch size, he learns smth useful?
#
# Important: check the KSD. Is it much higher?
# Also compare run KSD of vanilla ard with run KSD of funnel optimal kernel.

# %%
train_args = config.get_train_args(conf_mlp)
key, subkey = random.split(key)
encoder_params_mlp, rundata_mlp = svgd_mlp.train_kernel(key, **train_args)

# %%
t_mean = onp.array(rundata_mlp["training_mean"])
v_mean = onp.array(rundata_mlp["validation_mean"])
l_mean = onp.array(rundata_mlp["leader_mean"])

v_var = onp.array(rundata_mlp["validation_var"])
t_var = onp.array(rundata_mlp["training_var"])
l_var = onp.array(rundata_mlp["leader_var"])

tru_mean = svgd_mlp.target.mean
tru_var = onp.diag(svgd_mlp.target.cov)

# fig, axs = plt.subplots(1, 2, figsize=[22, 4])
# plot_rundata(tru_mean, l_mean, t_mean, v_mean, labels=[c + " Mean"     for c in ("Leader", "Training", "Validation")], ax=axs[0])
# plot_rundata(tru_var,  l_var,  t_var,  v_var,  labels=[c + " Variance" for c in ("Leader", "Training", "Validation")], ax=axs[1])

# %%
idx = np.arange(0, 2*50, 50) + 50

fig, ax = plt.subplots(figsize=[10, 5])
ax.plot(rundata_mlp["bandwidth"], "--.", label="Bandwidth")
ax.plot(idx, t_var, "--.", label="Var")

# ax.set_yscale("log")
_ = ax.legend()

# %%
1 / encoder_params_mlp["encoder/~/linear_0"]["w"]**2

# %%
fig, ax = plt.subplots(figsize=[10, 5])
ax.plot(rundata_mlp["ksd_before_kernel_update"], "--.", label="Training KSD")
# ax.plot(rundata_mlp["ksd_before_kernel_update_val"], ".", label="Validation KSD")
# ax.plot(rundata_mlp["ksd_after_svgd_update"], ".", label="KSD after SVGD step")
# ax.set_yscale("log")
_ = ax.legend()

# %%
fig, ax = plt.subplots(figsize=[10, 5])
section = list(range(0, 4000))
ax.plot(section, rundata_mlp["autoencoder_loss"][section] * train_args["lambda_reg"], label="autoencoder loss")
# ax.plot(section, rundata_mlp["regularized_loss"][section], label="Total loss = autoencoder - KSD")
ax.plot(section, rundata_mlp["ksd_before_kernel_update"][section], label="KSD")

ax.legend()
ax.set_yscale("log")

# %%
fig, axs = plt.subplots(1, 2, figsize=[18, 8])
axs[0].plot(rundata_mlp["mean_drift"], label="Mean Drift")
axs[0].legend()
axs[1].plot(rundata_mlp["mean_repulsion"], label="Mean Repulsion")
# axs[1].set_yscale("log")
axs[1].legend()

# %%
plt.plot(rundata_mlp["ksd_variance_val"])
plt.yscale("log")

# %%
plot.bivariate_hist(rundata_mlp["particles"])

# %%
rundata_mlp["is_pd"]

# %% [markdown]
# ## update-to-weight-ratio

# %%
def plot_update_to_weight_ratio(update_to_weight_ratio, scale="log"):
    con = update_to_weight_ratio
    def visit(d, prefix=""):
        for k, v in d.items():
            if type(v) is jax.interpreters.xla.DeviceArray or type(v) is onp.ndarray or type(v) is list:
                plt.plot(v, label=prefix+"//"+k)
            else:
                visit(v, k)
    visit(con)
    plt.yscale(scale)
    plt.legend()

# %%
plot_update_to_weight_ratio(rundata_mlp["update_to_weight_ratio"])

# %% [markdown]
# ## encoded / decoded

# %%
def enc(x): return svgd_mlp.encoder.apply(encoder_params_mlp, None, x)
def dec(x): return svgd_mlp.decoder.apply(rundata_mlp["decoder_params"], None, x)

# %%
sample = svgd_mlp.target.sample(1000)
encoded = vmap(enc)(sample)
decoded = vmap(dec)(encoded)

# %%
plot.bivariate_hist(sample)

# %%
plot.bivariate_hist(encoded)

# %%
plot.bivariate_hist(decoded)

# %%
_ = plt.hist(out[:, 1], bins=30)

# %%
# n_iter = conf_mlp["train_kernel"]["n_iter"]
# # ksd_kernel = np.split(rundata_mlp["ksd_after_kernel_update"], n_iter)
# # ksd_svgd = np.split(rundata_mlp["ksd_after_svgd_update"], n_iter)
# ksd_kernel = rundata_mlp["ksd_after_kernel_update"]

#     ax.plot(ksdss)


# for i, ksds in enumerate(ksd_kernel):
#     idx = range(40*i, 40*i+20)
# #     print("k range:", idx)
#     ax.plot(idx, ksds, ".b")

# for i, ksds in enumerate(ksd_svgd):
#     start = 40*(i+1) - 20
#     stop = 40*(i+1)
#     step = 5
#     idx = range(start, stop, step)
# #     print("s range:", idx)
#     ax.plot(idx, ksds, ".r")
