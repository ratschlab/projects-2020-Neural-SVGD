# %% [markdown]
# # Optimizing the KSD

# %%
from jax import config
config.update("jax_debug_nans", True)

import sys
import os
sys.path.append("/home/lauro/code/msc-thesis/svgd/kernel_learning/")
import json_tricks as json
import copy
from functools import partial

from tqdm import tqdm
import jax.numpy as np
from jax import grad, jit, vmap, random, lax, jacfwd, value_and_grad
from jax import lax
from jax.ops import index_update, index
import matplotlib.pyplot as plt
import numpy as onp
import jax
import pandas as pd
import haiku as hk
from jax.experimental import optimizers

import config

import utils
import metrics
import time
import plot
import stein
import kernels
import svgd
import distributions
import nets

from jax.experimental import optimizers

key = random.PRNGKey(0)
# Out:
# /home/lauro/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/lib/xla_bridge.py:125: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %% [markdown]
# ## Define Kernels

# %%
def get_rbf_fn(bandwidth):
    def rbf(x, y): 
        x, y = np.asarray(x), np.asarray(y)
        return np.exp(- np.sum((x - y)**2 / bandwidth**2) / 2)
    return rbf

# other kernels for comparison
def get_tophat_fn(bandwidth):
    def tophat(x, y): return np.squeeze(np.where(np.linalg.norm(x-y)<bandwidth, 1., 0.))
    return tophat

def constant(x, y): return np.array(1.)

def funnelize(v):
    """If v is standard 2D normal, then
    funnelize(v) is distributed as Neal's Funnel."""
    *x, y = v
    x, y = np.asarray(x), np.asarray(y)
    return np.append(x*np.exp(3*y/2), 3*y)

def defunnelize(z):
    """Inverse of funnelize."""
    *x, y = z
    x, y = np.asarray(x), np.asarray(y)
    return np.append(x*np.exp(-y/2), y/3)

def get_funnel_fn(bandwidth):
    rbf = get_rbf_fn(bandwidth)
    def funnel_kernel(x, y):
        return rbf(defunnelize(x), defunnelize(y))
    return funnel_kernel

# %% [markdown]
# ## Build Optimizer

# %%
class KSDLearner():
    def __init__(self, 
                 key, 
                 sizes, 
                 activation_kernel, 
                 proposal,
                 target,
                 learning_rate: float = 0.01,
                 lambda_reg: float = 0.1):
        """
        When sizes = [d] and no biases, then this is equivalent to just maximizing the
        vanilla RBF parameters (bandwidth / ARD covariance matrix).
        """
        self.sizes = sizes
        self.activation_kernel = activation_kernel
        self.proposal = proposal
        self.target = target
        self.lambda_reg = lambda_reg
        
        # net and optimizer
        self.mlp = nets.build_mlp(self.sizes, name="MLP", skip_connection=False)
        self.opt = svgd.Optimizer(*optimizers.adam(learning_rate))
        self.step = 0
        self.initialize_optimizer(key)
        
        # logs
        self.training_ksds = []
        self.autoenc_losses = []
        self.training_params = []
            
    def initialize_optimizer(self, key):
        # initialize optimizer
        x_dummy = np.ones(self.proposal.d)
        key, subkey = random.split(key)
        init_params = self.mlp.init(subkey, x_dummy)
        self.optimizer_state = self.opt.init((init_params, init_params))
        return None
    
    def get_kernel_fn(self, params):
        def kernel(x, y):
            x, y = np.asarray(x), np.asarray(y)
            return self.activation_kernel(self.mlp.apply(params, None, x), 
                                          self.mlp.apply(params, None, y))
        return kernel

    def loss_fn(self, params, samples):
        encoder_params, decoder_params = params
        kernel = self.get_kernel_fn(encoder_params)
        ksd = stein.ksd_squared_u(samples, self.target.logpdf, kernel, False)
        def enc(x): return self.mlp.apply(encoder_params, None, x)
        def dec(z): return self.mlp.apply(decoder_params, None, z)
        def autoencoder_loss(x): return np.linalg.norm(x - dec(enc(x)))**2
        autoenc_loss = np.mean(vmap(autoencoder_loss)(samples))
        aux = [ksd, autoenc_loss*self.lambda_reg]
        return -ksd + self.lambda_reg * autoenc_loss, aux

    @partial(jit, static_argnums=0)
    def update_step(self, optimizer_state, samples, step: int):
        # update step
        params = self.opt.get_params(optimizer_state)
        [loss, aux], g = value_and_grad(self.loss_fn, has_aux=True)(params, samples)
        optimizer_state = self.opt.update(step, g, optimizer_state)
        return optimizer_state, aux
        
    def train(self, n_steps=100, batch_size=400):
        for _ in tqdm(range(n_steps)):
            samples = proposal.sample(batch_size)
            self.step += 1
            self.optimizer_state, aux = self.update_step(self.optimizer_state, samples, self.step)
            ksd, autoenc_loss = aux
            self.training_ksds.append(ksd)
            self.autoenc_losses.append(autoenc_loss)
            self.training_params.append(self.opt.get_params(self.optimizer_state)[0]["MLP/~/linear_0"]["w"])
        return None
    
    @partial(jit, static_argnums=0)    
    def estimate_ksd_squared(self, params):
        k = self.get_kernel_fn(params)
        ksd = stein.ksd_squared_u(samples, self.target.logpdf, k, False)
        
    def compute_final_loss_mean_and_stddev(self):
        ksds_tail = self.training_ksds[-50:]
        return onp.mean(ksds_tail), onp.std(ksds_tail)

# %%
# estimate KSD and Var(\hat KSD) values for base kernels
def estimate_ksd_and_stddev(n: int, m: int, kernels, proposal, target):
    """
    n: number of particles
    m: number of draws for variance estimation
    kernels: list of kernel functions
    
    Returns
    ksds: mean ksd value for each kernel
    stds: standard dev for each kernel
    """
    ksds_list = [[] for kernel in kernels]
    @partial(jit, static_argnums=1)
    def sample_ksd(samples, kernel):
        return stein.ksd_squared_u(samples, target.logpdf, kernel, False)
    for _ in tqdm(range(m)):
        samples = proposal.sample(n)
        for kernel_ksds, kernel in zip(ksds_list, kernels):
            ksd = sample_ksd(samples, kernel)
            kernel_ksds.append(ksd)
    
    ksds = onp.mean(ksds_list, axis=1)
    stds = onp.std(ksds_list, axis=1)
    return ksds, stds

# %% [markdown]
# #### Plot everything

# %%
def plot_training(training_ksds, ksds, stds, ax=None, lims=None):
    if ax is None:
        ax = plt.gca()
    grid_ksds = np.asarray(training_ksds)
    ax.plot(grid_ksds, "--k", label="Optimized KSD")

    labels = ("k(x, y)=1 constant", "RBF with bandwidth 1", "RBF composed with funnel")
    cycle = iter(plt.rcParams['axes.prop_cycle'].by_key()['color'])
    for label, ksd, std, errorbar_xpos in zip(labels, ksds, stds, len(grid_ksds)*np.array([1/3, 2/3, 0.9])):
        col = next(cycle)
        ax.axhline(y=ksd, label=label, color=col, linestyle="--")
        ax.errorbar(errorbar_xpos, ksd, yerr=std, color=col, capsize=5, label="Standard deviation")
    ax.set_xlabel("Steps")
    ax.set_ylabel("KSD")

    ax.set_ylim(lims)
    _ = ax.legend()

# %% [markdown]
# ### Parameters

# %%
# proposal = distributions.FunnelizedGaussian([1, 1], 1)
# target = distributions.Funnel(2)
# sizes = [8, 8, 8, 2]

# %%
# proposal = distributions.Gaussian([0, 0], 1)
# target = distributions.Gaussian([-2, 3], 2)
# sizes = [8, 8, 8, 2]

# %%
proposal = distributions.Gaussian(0, 5)
target = distributions.Gaussian(0, 15)
sizes = [1]

# %%
# proposal = distributions.GaussianMixture([0, 6.3], [3, 1], [1/2, 1/2])
# target = distributions.GaussianMixture([0, 6, 7, 9], [1, 2, 6, 10], [1/2, 1/6, 1/6, 1/6])

# %%
plot.plot_fun(target.pdf, (-10, 10))
plot.plot_fun(proposal.pdf, (-10, 10))

# %% [markdown]
# ### Train

# %%
# sizes = [4, 4, 1]

# %%
learner = KSDLearner(key, sizes, get_rbf_fn(1), proposal, target, .1, 0.)

# %%
# params = {k: dict(v) for k, v in learner.opt.get_params(learner.optimizer_state)[0].items()}
# params["MLP/~/linear_0"]["w"] = np.asarray([[1/5]])
# learner.optimizer_state = learner.opt.init((params, params))

# %%
print("Training kernel to optimize KSD...")
learner.train(n_steps=50, batch_size=400)
loss_mean, loss_std = learner.compute_final_loss_mean_and_stddev()
# Out:
#   0%|          | 19/17500 [00:00<01:35, 182.80it/s]
# Training kernel to optimize KSD...
# 100%|██████████| 17500/17500 [01:25<00:00, 204.07it/s]

# %%
print("Computing KSDs with base kernels for comparison...")
kernel_list = [constant, get_rbf_fn(1)]
if isinstance(target, distributions.Funnel):
    kernel_list.append(get_funnel_fn(1))
ksds, stds = onp.array(estimate_ksd_and_stddev(400, 1000, kernel_list, 
                                              proposal, target))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Computing KSDs with base kernels for comparison...
# 100%|██████████| 1000/1000 [00:02<00:00, 389.63it/s]

# %%
print("Plot results:")
fig, ax = plt.subplots(figsize=[10,8])
plot_training(learner.training_ksds, ksds, stds, ax)
plt.plot(learner.autoenc_losses, label="Autoencoder loss", color="purple")

plt.legend()
# _ = ax.errorbar(len(learner.losses)-25, -loss_mean, yerr=loss_std, capsize=5, color="k")
# Out:
# Plot results:

# %%
fig, ax = plt.subplots(figsize=[10,8])
bandwidths = np.squeeze(1 / np.asarray(learner.training_params)**2)
plt.plot(bandwidths, "--o", label="Bandwidth", color="green")
plt.axhline(bandwidths[-1])
plt.yscale("log")
plt.legend()

# %%
params, _ = learner.opt.get_params(learner.optimizer_state)
learned_kernel = learner.get_kernel_fn(params)

# %%
s = proposal.sample(100)
learned_kernel(s[4], s[10])
# Out:
# DeviceArray(0.27138123, dtype=float32)

# %%
params
# Out:
# frozendict({
#   'MLP/~/linear_0': frozendict({
#                       'b': DeviceArray([-3.6161532], dtype=float32),
#                       'w': DeviceArray([[3.4085107]], dtype=float32),
#                     }),
# })

# %% [markdown]
# # Plot the kernel

# %%
grid = np.linspace(-4, 10, 100).reshape(100,1)
x = np.array([0.])
plt.plot(grid, vmap(learned_kernel, (0, None))(grid, x), label="Learned", color="r")
plt.plot(grid, vmap(get_rbf_fn(1),  (0, None))(grid, x), label="RBF", color="b")
x = np.array([4.])
plt.plot(grid, vmap(learned_kernel, (0, None))(grid, x), color="r")
plt.plot(grid, vmap(get_rbf_fn(1),  (0, None))(grid, x), color="b")

plt.legend()
