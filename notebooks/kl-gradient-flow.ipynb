# %% [markdown]
# # KL gradient flow

# %%
import sys
sys.path.append("/home/lauro/code/msc-thesis/svgd/kernel_learning/")

import jax.numpy as np
from jax import jit, vmap, random, value_and_grad, grad
from jax.experimental import optimizers
from jax.ops import index_update, index
import haiku as hk
import jax
import numpy as onp

import traceback
import time
from tqdm import tqdm
from functools import partial
import json_tricks as json

import utils
import metrics
import stein
import kernels
import nets
import distributions
import kernel_learning

import os
on_cluster = not os.getenv("HOME") == "/home/lauro"
disable_tqdm = on_cluster
# Out:
# /home/lauro/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/lib/xla_bridge.py:125: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
class KLFlow():
    def __init__(self,
                 key,
                 target,
                 proposal,
                 n_particles: int = 400,
                 learning_rate=0.1,
                 debugging_config=None):
        """
        Arguments
        ----------
        target, proposal: instances of class distributions.Distribution
        optimizer_svgd needs to have pure methods
           optimizer_svgd.init(params) -> state
           optimizer_svgd.update(key, gradient, state) -> state
           optimizer_svgd.get_params(state) -> params
        """
        self.target = target
        self.proposal = proposal
        self.n_particles = n_particles
        self.debugging_config = debugging_config

        # optimizer for particle updates
        self.opt = kernel_learning.Optimizer(*optimizers.sgd(learning_rate))
        self.step_counter = 0
        self.rundata = {}
        self.threadkey, subkey = random.split(key)
        self.initialize_optimizer(subkey)

        # to track KL
        self.pullback_logp = target.logpdf

    def initialize_optimizer(self, key):
        particles = self.init_particles(key)
        self.optimizer_state = self.opt.init(particles)
        return None

    def init_particles(self, key):
        particle_shape = (self.n_particles, self.target.d)
        particles = self.proposal.sample(self.n_particles, key=key)
        assert particles.shape == particle_shape
        return particles

    def logdiff(self, x, logp):
        return self.proposal.logpdf(x) - logp(x)

    def kl(self, samples, logp):
        return np.mean(vmap(self.logdiff, (0, None))(samples, logp))

    @partial(jit, static_argnums=0)
    def _step(self, optimizer_state, logps, grad_logps, step_counter):
        """
        Updates particles in direction of the SVGD gradient.
        Arguments
            logps: shape (n, d)
            grad_logps: shape (n, d)
        Returns
        * updated optimizer_state
        * dKL: np array of same shape as followers (n, d)
        * auxdata consisting of [mean_drift, mean_repulsion] of shape (n, 2, d)
        """
        particles = self.opt.get_params(optimizer_state)
#         KL, dKL = value_and_grad(self.kl)(particles, logp)
        logqs, grad_logqs = vmap(value_and_grad(proposal.logpdf))(particles)
        KL = np.mean(logqs - logps)
        dKL = np.mean(grad_logqs - grad_logps)
        optimizer_state = self.opt.update(step_counter, dKL, optimizer_state)
        auxdata = (KL, dKL)
        return optimizer_state, auxdata

    def step(self):
        """Log rundata, take step, update loglikelihood. Mutates state"""
        logps, grad_logps = self.logp_value_and_grad()
        updated_optimizer_state, auxdata = self._step(
            self.optimizer_state, logps, grad_logps, self.step_counter)
        self.log(auxdata)
        self.update_logp()
        self.optimizer_state = updated_optimizer_state # take step
        self.step_counter += 1
        return None

    def get_params(self):
        return self.opt.get_params(self.optimizer_state)

    def log(self, auxdata):
        particles = self.opt.get_params(self.optimizer_state)
        KL, dKL = auxdata
        metrics.append_to_log(self.rundata, {
            "step": self.step_counter,
            "gradient_norm": np.linalg.norm(dKL),
            "mean": np.mean(particles),
            "std": np.std(particles),
        })

    @partial(jit, static_argnums=0)
    def transformation(self, x, particles, step_counter):
        # inject x
        particles_with_inject = index_update(particles, index[0], x)
        optimizer_state_with_inject = self.opt.init(particles_with_inject)

        # step
        updated_optimizer_state, *_ = self._step(
            optimizer_state_with_inject, >>>>>> ,step_counter)

        # extract z = T(x)
        updated_particles = self.opt.get_params(updated_optimizer_state)
        z = updated_particles[follower_idx[0]]
        return z

    def update_logp(self):
        def t(x):
            return self.transformation(x, self.get_params(), self.step_counter)
        self.pullback_logp = metrics._pushforward_log(self.pullback_logp, t)

    def logp_value_and_grad(self):
        return vmap(value_and_grad(self.pullback_logp))(self.get_params())

    def flow(self, key=None, n_iter=400):
        if key is None:
            self.threadkey, key = random.split(self.threadkey)
        for i in tqdm(range(n_iter), disable=disable_tqdm):
            self.step()
            key, subkey = random.split(key)

# %%
proposal = distributions.Gaussian(0, 5)
target = distributions.Gaussian(0, 1)

# %%
key = random.PRNGKey(0)
k = KLFlow(key,
          target=target,
          proposal=proposal)

# %%
k.flow()
# Out:
#   0%|          | 1/400 [00:00<01:12,  5.48it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-3673aa9ceaa3> in <module>
# ----> 1 k.flow()
#
# <ipython-input-10-0895f3c19a5c> in flow(self, key, n_iter)
#     122             self.threadkey, key = random.split(self.threadkey)
#     123         for i in tqdm(range(n_iter), disable=disable_tqdm):
# --> 124             self.step()
#     125             key, subkey = random.split(key)
#
# <ipython-input-10-0895f3c19a5c> in step(self)
#      71     def step(self):
#      72         """Log rundata, take step, update loglikelihood. Mutates state"""
# ---> 73         logps, grad_logps = self.logp_value_and_grad()
#      74         updated_optimizer_state, auxdata = self._step(
#      75             self.optimizer_state, logps, grad_logps, self.step_counter)
#
# <ipython-input-10-0895f3c19a5c> in logp_value_and_grad(self)
#     116
#     117     def logp_value_and_grad(self):
# --> 118         return vmap(value_and_grad(self.pullback_logp))(self.get_params())
#     119
#     120     def flow(self, key=None, n_iter=400):
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/api.py in batched_fun(*args)
#     867     in_axes_flat = flatten_axes(in_tree, in_axes)
#     868     _ = _mapped_axis_size(in_tree, args_flat, in_axes_flat, "vmap")
# --> 869     out_flat = batching.batch(flat_fun, args_flat, in_axes_flat,
#     870                               lambda: flatten_axes(out_tree(), out_axes))
#     871     return tree_unflatten(out_tree(), out_flat)
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/batching.py in batch(fun, in_vals, in_dims, out_dim_dests)
#      32   # executes a batched version of `fun` following out_dim_dests
#      33   batched_fun = batch_fun(fun, in_dims, out_dim_dests)
# ---> 34   return batched_fun.call_wrapped(*in_vals)
#      35
#      36 @lu.transformation_with_aux
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     148     gen = None
#     149
# --> 150     ans = self.f(*args, **dict(self.params, **kwargs))
#     151     del args
#     152     while stack:
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     469     tree_map(partial(_check_input_dtype_grad, holomorphic), dyn_args)
#     470     if not has_aux:
# --> 471       ans, vjp_py = _vjp(f_partial, *dyn_args)
#     472     else:
#     473       ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/api.py in _vjp(fun, *primals, **kwargs)
#    1553   if not has_aux:
#    1554     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1555     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1556     out_tree = out_tree()
#    1557   else:
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     107 def vjp(traceable, primals, has_aux=False):
#     108   if not has_aux:
# --> 109     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     110   else:
#     111     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      94   _, in_tree = tree_flatten(((primals, primals), {}))
#      95   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# ---> 96   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#      97   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#      98   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate, stage_out, bottom, trace_type)
#     427   with new_master(trace_type, bottom=bottom) as master:
#     428     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 429     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     430     assert not env
#     431     del master
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     148     gen = None
#     149
# --> 150     ans = self.f(*args, **dict(self.params, **kwargs))
#     151     del args
#     152     while stack:
#
# ~/code/msc-thesis/svgd/kernel_learning/metrics.py in pushforward_logpdf(z)
#      83     """
#      84     def pushforward_logpdf(z):
# ---> 85         det = np.linalg.det(jacfwd(tinv)(z))
#      86 #         if np.abs(det) < 0.001:
#      87 #             raise LinalgError("Determinant too small: T is not injective.")
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/api.py in jacfun(*args, **kwargs)
#     565     tree_map(partial(_check_input_dtype_jacfwd, holomorphic), dyn_args)
#     566     pushfwd = partial(_jvp, f_partial, dyn_args)
# --> 567     y, jac = vmap(pushfwd, out_axes=(None, batching.last))(_std_basis(dyn_args))
#     568     tree_map(partial(_check_output_dtype_jacfwd, holomorphic), y)
#     569     example_args = dyn_args[0] if isinstance(argnums, int) else dyn_args
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/api.py in batched_fun(*args)
#     867     in_axes_flat = flatten_axes(in_tree, in_axes)
#     868     _ = _mapped_axis_size(in_tree, args_flat, in_axes_flat, "vmap")
# --> 869     out_flat = batching.batch(flat_fun, args_flat, in_axes_flat,
#     870                               lambda: flatten_axes(out_tree(), out_axes))
#     871     return tree_unflatten(out_tree(), out_flat)
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/batching.py in batch(fun, in_vals, in_dims, out_dim_dests)
#      32   # executes a batched version of `fun` following out_dim_dests
#      33   batched_fun = batch_fun(fun, in_dims, out_dim_dests)
# ---> 34   return batched_fun.call_wrapped(*in_vals)
#      35
#      36 @lu.transformation_with_aux
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     148     gen = None
#     149
# --> 150     ans = self.f(*args, **dict(self.params, **kwargs))
#     151     del args
#     152     while stack:
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/api.py in _jvp(fun, primals, tangents)
#    1385       raise TypeError(msg.format(_dtype(p), _dtype(t)))
#    1386   flat_fun, out_tree = flatten_fun_nokwargs(fun, tree_def)
# -> 1387   out_primals, out_tangents = ad.jvp(flat_fun).call_wrapped(ps_flat, ts_flat)
#    1388   return (tree_unflatten(out_tree(), out_primals),
#    1389           tree_unflatten(out_tree(), out_tangents))
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     148     gen = None
#     149
# --> 150     ans = self.f(*args, **dict(self.params, **kwargs))
#     151     del args
#     152     while stack:
#
# <ipython-input-10-0895f3c19a5c> in t(x)
#     112     def update_logp(self):
#     113         def t(x):
# --> 114             return self.transformation(x, self.get_params(), self.step_counter)
#     115         self.pullback_logp = metrics._pushforward_log(self.pullback_logp, t)
#     116
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     167     for arg in args_flat: _check_arg(arg)
#     168     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 169     out = xla.xla_call(flat_fun, *args_flat, device=device, backend=backend,
#     170                        name=flat_fun.__name__, donated_invars=donated_invars)
#     171     return tree_unflatten(out_tree(), out)
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1101   else:
#    1102     tracers = map(top_trace.full_raise, args)
# -> 1103     outs = primitive.process(top_trace, fun, tracers, params)
#    1104   return apply_todos(env_trace_todo(), map(full_lower, outs))
#    1105
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1110
#    1111   def process(self, trace, fun, tracers, params):
# -> 1112     return trace.process_call(self, fun, tracers, params)
#    1113
#    1114   def post_process(self, trace, out_tracers, params):
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     268     update_params = call_param_updaters.get(call_primitive)
#     269     new_params = update_params(params, nz_tangents) if update_params else params
# --> 270     result = call_primitive.bind(f_jvp, *primals, *nonzero_tangents, **new_params)
#     271     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     272     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1101   else:
#    1102     tracers = map(top_trace.full_raise, args)
# -> 1103     outs = primitive.process(top_trace, fun, tracers, params)
#    1104   return apply_todos(env_trace_todo(), map(full_lower, outs))
#    1105
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1110
#    1111   def process(self, trace, fun, tracers, params):
# -> 1112     return trace.process_call(self, fun, tracers, params)
#    1113
#    1114   def post_process(self, trace, out_tracers, params):
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/batching.py in process_call(self, call_primitive, f, tracers, params)
#     146     else:
#     147       f, dims_out = batch_subtrace(f, self.master, dims)
# --> 148       vals_out = call_primitive.bind(f, *vals, **params)
#     149       return [BatchTracer(self, v, d) for v, d in zip(vals_out, dims_out())]
#     150
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1101   else:
#    1102     tracers = map(top_trace.full_raise, args)
# -> 1103     outs = primitive.process(top_trace, fun, tracers, params)
#    1104   return apply_todos(env_trace_todo(), map(full_lower, outs))
#    1105
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1110
#    1111   def process(self, trace, fun, tracers, params):
# -> 1112     return trace.process_call(self, fun, tracers, params)
#    1113
#    1114   def post_process(self, trace, out_tracers, params):
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     268     update_params = call_param_updaters.get(call_primitive)
#     269     new_params = update_params(params, nz_tangents) if update_params else params
# --> 270     result = call_primitive.bind(f_jvp, *primals, *nonzero_tangents, **new_params)
#     271     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     272     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1101   else:
#    1102     tracers = map(top_trace.full_raise, args)
# -> 1103     outs = primitive.process(top_trace, fun, tracers, params)
#    1104   return apply_todos(env_trace_todo(), map(full_lower, outs))
#    1105
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1110
#    1111   def process(self, trace, fun, tracers, params):
# -> 1112     return trace.process_call(self, fun, tracers, params)
#    1113
#    1114   def post_process(self, trace, out_tracers, params):
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in process_call(self, primitive, f, tracers, params)
#     184                   else PartialVal.unknown(mapped_aval(pval[0]))
#     185                   for pval, is_mapped in zip(in_pvals, params['mapped_invars'])]
# --> 186     jaxpr, out_pvals, consts, env_tracers = self.partial_eval(
#     187         f, in_pvals, partial(primitive.bind, **params))
#     188     if primitive.map_primitive:
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in partial_eval(self, f, pvals, app)
#     296     f = trace_to_subjaxpr(f, self.master, False)
#     297     f, aux = partial_eval_wrapper(f, tuple(in_avals))
# --> 298     out_flat, (out_avals, jaxpr, env) = app(f, *in_consts), aux()
#     299     out_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#     300     out_pvs = map(PartialVal, zip(out_avals, out_consts))
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1101   else:
#    1102     tracers = map(top_trace.full_raise, args)
# -> 1103     outs = primitive.process(top_trace, fun, tracers, params)
#    1104   return apply_todos(env_trace_todo(), map(full_lower, outs))
#    1105
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1110
#    1111   def process(self, trace, fun, tracers, params):
# -> 1112     return trace.process_call(self, fun, tracers, params)
#    1113
#    1114   def post_process(self, trace, out_tracers, params):
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/batching.py in process_call(self, call_primitive, f, tracers, params)
#     146     else:
#     147       f, dims_out = batch_subtrace(f, self.master, dims)
# --> 148       vals_out = call_primitive.bind(f, *vals, **params)
#     149       return [BatchTracer(self, v, d) for v, d in zip(vals_out, dims_out())]
#     150
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1098   if top_trace is None:
#    1099     with new_sublevel():
# -> 1100       outs = primitive.impl(fun, *args, **params)
#    1101   else:
#    1102     tracers = map(top_trace.full_raise, args)
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     539
#     540 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
# --> 541   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     542                                *unsafe_map(arg_spec, args))
#     543   try:
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     219       fun.populate_stores(stores)
#     220     else:
# --> 221       ans = call(fun, *args)
#     222       cache[key] = (ans, fun.stores)
#     223     return ans
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     605   abstract_args, arg_devices = unzip2(arg_specs)
#     606   pvals: Sequence[pe.PartialVal] = [pe.PartialVal.unknown(aval) for aval in abstract_args]
# --> 607   jaxpr, pvals, consts = pe.trace_to_jaxpr(
#     608       fun, pvals, instantiate=False, stage_out=True, bottom=True)
#     609   map(prefetch, it.chain(consts, jaxpr_literals(jaxpr)))
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate, stage_out, bottom, trace_type)
#     427   with new_master(trace_type, bottom=bottom) as master:
#     428     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 429     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     430     assert not env
#     431     del master
#
# ~/.virtualenvs/msc-thesis/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     148     gen = None
#     149
# --> 150     ans = self.f(*args, **dict(self.params, **kwargs))
#     151     del args
#     152     while stack:
#
# <ipython-input-10-0895f3c19a5c> in transformation(self, x, particles, step_counter)
#      95     @partial(jit, static_argnums=0)
#      96     def transformation(self, x, particles, step_counter):
# ---> 97         _, follower_idx = self.group_idx
#      98
#      99         # inject x
#
# AttributeError: 'KLFlow' object has no attribute 'group_idx'
